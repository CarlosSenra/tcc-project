# %%
import os
import pandas as pd
from omegaconf import OmegaConf
import matplotlib.pyplot as plt


config = OmegaConf.load("gru_config.yaml")

# %%
def results_dataframe():
    """
    Lê e combina dados de múltiplos arquivos CSV em diferentes diretórios.
    
    Returns:
        DataFrame: Combina todos os CSVs encontrados com uma coluna adicional 'Model_covariates'
                  indicando o diretório de origem.
    """
    df_aux = pd.DataFrame()
    for directory in os.listdir(config.paths.eval_folder):
        for csv in os.listdir(config.paths.eval_folder+directory):
            df_temp = pd.read_csv(config.paths.eval_folder+directory+"/"+csv)
            df_temp['Model_covariates'] = directory
            df_aux = pd.concat([df_aux,df_temp])
    return df_aux

def house_result_variation_calculate(house,df_):
    """
    Calcula a variação das métricas de avaliação para uma casa específica em relação
    ao modelo base (#).
    
    Args:
        house: Identificador da casa a ser analisada
        
    Returns:
        DataFrame: Dados originais com colunas adicionais mostrando as variações das métricas
    """
    df_filtred = df_[df_.House_Hold == house]
    metrics_values = df_filtred[["MAE","SMAPE","RMSE"]].loc[df_filtred.Model_covariates == "#"]
    variation = df_filtred[["MAE","SMAPE","RMSE"]].sub(metrics_values)
    variation.rename(columns={a:b for a,b in zip(variation.columns,[x+"_variation" for x in variation.columns])},inplace=True)
    variation = pd.concat([df_filtred,variation],axis=1)
    return variation


def check_better_results(df_house_variation):
    """
    Analisa as variações e identifica onde houve melhorias nas métricas.
    Uma variação negativa indica melhoria em relação ao modelo base.
    Depois soma as colunas resumindo as variaveis booleanas

    Args:
        df_house_variation: DataFrame com as variações calculadas
        
    Returns:
        DataFrame: Sumário das melhorias por casa, onde para cada coluna apresenta a soma de quantas vezes uma covariavel adicionada ao modelo 
                   apresentou melhor desempenho que o modelo sem covariaveis
    """
    df_temp = df_house_variation
    for variation in df_temp.columns[-3:]:
        name_col = variation+"_bool"
        df_temp[name_col] = df_temp[variation].apply(lambda x : 1 if x < 0 else 0)
    df_better_results = df_temp[["House_Hold","MAE_variation_bool","SMAPE_variation_bool","RMSE_variation_bool"]].groupby("House_Hold").sum()
    df_better_results = df_better_results.reset_index()
    return df_better_results


def condense_results():
    """
    Função principal que coordena todo o processo de análise.
    Processa os dados de todas as casas e gera um relatório final
    mostrando onde houve melhorias nas métricas. 
    Salva em um csv.
    
    Returns:
        DataFrame: Resumo final das melhorias por casa
    """
    df_temp = results_dataframe()
    df_aux = pd.DataFrame()
    for house in df_temp.House_Hold.unique():
        a = house_result_variation_calculate(house,df_temp)
        b = check_better_results(a)
        df_aux = pd.concat([df_aux,b])
    df_aux.sort_values("MAE_variation_bool",ascending=False,inplace=True)
    df_aux.to_csv("resultados_condensados.csv")    
    return df_aux.sort_values("MAE_variation_bool",ascending=False)

# %%
df = results_dataframe()
df_auxiliar = pd.DataFrame()
for house in df.House_Hold.unique():
    a = house_result_variation_calculate(house,df)
    df_auxiliar = pd.concat([df_auxiliar,a])
df_auxiliar[~df_auxiliar.House_Hold.isin(df_auxiliar[df_auxiliar.MAE_variation.isnull()].House_Hold.unique())]
# Out:
#                                  House_Hold    MAE         MAPE  SMAPE   RMSE  \
# 0       STRETCHEDSOCIETY_BLOCK_91_MAC001165  0.071  1144529.400  1.050  0.150
# 0       STRETCHEDSOCIETY_BLOCK_91_MAC001165  0.056   608943.440  0.971  0.132
# 0       STRETCHEDSOCIETY_BLOCK_91_MAC001165  0.070  1083918.500  1.032  0.150
# 0       STRETCHEDSOCIETY_BLOCK_91_MAC001165  0.070  1214319.500  1.032  0.149
# 0       STRETCHEDSOCIETY_BLOCK_91_MAC001165  0.070  1125292.200  1.028  0.150
# ..                                      ...    ...          ...    ...    ...
# 0   ESTABLISHEDAFFLUENCE_BLOCK_35_MAC001111  0.072        0.394  0.340  0.107
# 0   ESTABLISHEDAFFLUENCE_BLOCK_35_MAC001111  0.072        0.227  0.311  0.143
# 0   ESTABLISHEDAFFLUENCE_BLOCK_35_MAC001111  0.086        0.424  0.421  0.130
# 0   ESTABLISHEDAFFLUENCE_BLOCK_35_MAC001111  0.081        0.362  0.388  0.132
# 0   ESTABLISHEDAFFLUENCE_BLOCK_35_MAC001111  0.072        0.229  0.309  0.142
#
#    Time_execution             Model_covariates  MAE_variation  \
# 0         338.61s                dayofweek_num          0.001
# 0         333.01s                         hour         -0.014
# 0         320.20s                      holiday          0.000
# 0         321.04s                        month          0.000
# 0         331.50s                            #          0.000
# ..            ...                          ...            ...
# 0         310.85s                         hour         -0.009
# 0         506.20s                   precipType         -0.009
# 0         316.79s                        month          0.005
# 0         309.75s                            #          0.000
# 0         844.22s  bool_weather_missing_values         -0.009
#
#     SMAPE_variation  RMSE_variation
# 0             0.022           0.000
# 0            -0.057          -0.018
# 0             0.004           0.000
# 0             0.004          -0.001
# 0             0.000           0.000
# ..              ...             ...
# 0            -0.048          -0.025
# 0            -0.077           0.011
# 0             0.033          -0.002
# 0             0.000           0.000
# 0            -0.079           0.010
#
# [575 rows x 10 columns]

# %%
def calculate_percentage_variation(house, df_):
   """
   Calcula a porcentagem de variação das métricas em relação ao modelo base.
   Args:
       house: Identificador da casa
       df_: DataFrame com os dados
   Returns:
       DataFrame: Dados com colunas de variação percentual 
   """
   # Aproveita função existente para obter variações
   df_variations = house_result_variation_calculate(house, df_)
   
   # Valores do modelo base
   base_values = df_variations[["MAE","SMAPE","RMSE"]].loc[df_variations.Model_covariates == "#"]
   pct_df = df_variations[["MAE","SMAPE","RMSE"]].div(base_values).sub(1).mul(100).round(2)
   pct_df.rename(columns={a:b for a,b in zip(pct_df.columns,[x+"_pct" for x in pct_df.columns])},inplace=True)
   pct_df = pd.concat([df_variations,pct_df],axis=1)
   return pct_df

# %%
df = results_dataframe()
df_auxiliar = pd.DataFrame()
for house in df.House_Hold.unique():
    a = calculate_percentage_variation(house,df)
    df_auxiliar = pd.concat([df_auxiliar,a])
df_auxiliar= df_auxiliar[~df_auxiliar.House_Hold.isin(df_auxiliar[df_auxiliar.MAE_variation.isnull()].House_Hold.unique())]
df_auxiliar[~df_auxiliar.House_Hold.isin(df_auxiliar[df_auxiliar.MAE_variation.isnull()].House_Hold.unique())].to_csv("pct_variacao.csv")
df_auxiliar = df_auxiliar[df_auxiliar.Model_covariates != "#"]

# %%
df_auxiliar[["House_Hold","MAE_pct","SMAPE_pct","RMSE_pct"]].groupby("House_Hold").mean().sort_values("MAE_pct",ascending=True).to_csv("media_variacao.csv")

# %%
import dtale
import dtale.global_state as global_state
global_state.set_app_settings(dict(enable_custom_filters=True))

df = pd.read_csv("pct_variacao.csv")
d = dtale.show(df)
d.kill()

# using Python's `webbrowser` package it will try and open your server's default browser to this process
d.open_browser()
# Out:
# Turning on custom filtering. Custom filters are vulnerable to code injection attacks, please only use in trusted environments.
# 2024-12-23 08:43:17,678 - WARNING  - Custom filtering enabled. Custom filters are vulnerable to code injection attacks, please only use in trusted environments.
# 2024-12-23 08:43:17,703 - INFO     - Shutdown complete

# %%
df = pd.read_csv("pct_variacao.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df1 = df[["MAE_pct", "SMAPE_pct", "RMSE_pct"]].rename(columns = {"MAE_pct":"MAE","SMAPE_pct":"SMAPE","RMSE_pct":"RMSE"})
# Configurando o estilo
sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))

# Criando o box plot com pontos
# Primeiro o boxplot
ax = sns.boxplot(data=df1, 
                palette="Blues",
                width=0.6,
                showfliers=False)

# Adicionando os pontos individuais
sns.stripplot(data=df1, 
             color='red',  # Cor dos pontos
             alpha=0.2,    # Transparência
             size=4,       # Tamanho dos pontos
             jitter=0.2)   # Dispersão horizontal dos pontos

# Personalizando o gráfico
plt.title(" ", 
          fontsize=14, 
          pad=20)
plt.ylabel("Avaliation Metrics Variation (%)", 
          fontsize=12)
plt.xlabel("Metrics", 
          fontsize=12)

# Ajustando os limites do eixo y
plt.ylim(-60, 60)

# Adicionando uma grade mais suave
ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.xaxis.grid(False)

# Personalizando as bordas
sns.despine(left=False, bottom=False)

# Ajustando o layout
plt.tight_layout()
plt.savefig('variacao_percentual_geral.png')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configurando o estilo
sns.set_style("whitegrid")
plt.figure(figsize=(12, 8))

# Criando o box plot com pontos
# Primeiro o boxplot
ax = sns.boxplot(data=df1, 
                palette="Blues",
                width=0.6,
                showfliers=False)

# Adicionando os pontos individuais
sns.swarmplot(data=df1, 
              color='red',
              alpha=0.2,
              size=4)  # Dispersão horizontal dos pontos

# Personalizando o gráfico
#plt.title("GRU models Results", 
 #         fontsize=18, 
  #        pad=20)
plt.ylabel("Avaliation Metrics Variation (%)", 
          fontsize=12)
plt.xlabel("Metrics", 
          fontsize=12)

# Ajustando os limites do eixo y
plt.ylim(-60, 60)

# Adicionando uma grade mais suave
ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.xaxis.grid(False)

# Personalizando as bordas
sns.despine(left=False, bottom=False)

# Ajustando o layout
plt.tight_layout()
plt.savefig('GRU_variacao_geral.png')

plt.show()
# Out:
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 21.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 16.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning:
#
# 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
def analyze_distribution(df, columns):
    """
    Analisa a distribuição dos dados por quartis e outliers para cada coluna especificada
    
    Parameters:
    df (pandas.DataFrame): DataFrame com os dados
    columns (list): Lista de colunas para análise
    
    Returns:
    dict: Dicionário com as análises por coluna
    """
    results = {}
    
    for col in columns:
        # Calcula os quartis
        Q1 = df[col].quantile(0.25)
        Q2 = df[col].quantile(0.50)  # mediana
        Q3 = df[col].quantile(0.75)
        
        # Calcula o IQR e os limites para outliers
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # Conta elementos em cada quartil
        first_quartile = df[(df[col] >= lower_bound) & (df[col] < Q1)][col].count()
        second_quartile = df[(df[col] >= Q1) & (df[col] < Q2)][col].count()
        third_quartile = df[(df[col] >= Q2) & (df[col] < Q3)][col].count()
        fourth_quartile = df[(df[col] >= Q3) & (df[col] <= upper_bound)][col].count()
        
        # Conta outliers
        outliers_low = df[df[col] < lower_bound][col].count()
        outliers_high = df[df[col] > upper_bound][col].count()
        
        results[col] = {
            'Primeiro Quartil': first_quartile,
            'Segundo Quartil': second_quartile,
            'Terceiro Quartil': third_quartile,
            'Quarto Quartil': fourth_quartile,
            'Outliers Negativos': outliers_low,
            'Outliers Positivos': outliers_high,
            'Limites': {
                'Q1': Q1,
                'Q2 (Mediana)': Q2,
                'Q3': Q3,
                'Limite Inferior': lower_bound,
                'Limite Superior': upper_bound
            }
        }
    
    return results

# Usando a função
colunas = ["MAE_pct", "SMAPE_pct", "RMSE_pct"]
resultados = analyze_distribution(df, colunas)

# Imprimindo os resultados de forma organizada
for metrica, dados in resultados.items():
    print(f"\nAnálise da métrica: {metrica}")
    print("-" * 50)
    print(f"Distribuição por quartis:")
    print(f"1º Quartil: {dados['Primeiro Quartil']} elementos")
    print(f"2º Quartil: {dados['Segundo Quartil']} elementos")
    print(f"3º Quartil: {dados['Terceiro Quartil']} elementos")
    print(f"4º Quartil: {dados['Quarto Quartil']} elementos")
    print(f"\nOutliers:")
    print(f"Negativos: {dados['Outliers Negativos']} elementos")
    print(f"Positivos: {dados['Outliers Positivos']} elementos")
    print(f"\nLimites:")
    for nome, valor in dados['Limites'].items():
        print(f"{nome}: {valor:.2f}")
# Out:
# Análise da métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 100 elementos
# 2º Quartil: 143 elementos
# 3º Quartil: 28 elementos
# 4º Quartil: 253 elementos
#
# Outliers:
# Negativos: 44 elementos
# Positivos: 7 elementos
#
# Limites:
# Q1: -11.72
# Q2 (Mediana): -1.30
# Q3: 0.00
# Limite Inferior: -29.30
# Limite Superior: 17.58
#
# Análise da métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 117 elementos
# 2º Quartil: 143 elementos
# 3º Quartil: 143 elementos
# 4º Quartil: 135 elementos
#
# Outliers:
# Negativos: 27 elementos
# Positivos: 10 elementos
#
# Limites:
# Q1: -13.31
# Q2 (Mediana): -1.45
# Q3: 0.40
# Limite Inferior: -33.88
# Limite Superior: 20.96
#
# Análise da métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 99 elementos
# 2º Quartil: 142 elementos
# 3º Quartil: 145 elementos
# 4º Quartil: 131 elementos
#
# Outliers:
# Negativos: 45 elementos
# Positivos: 13 elementos
#
# Limites:
# Q1: -9.54
# Q2 (Mediana): -1.09
# Q3: 0.29
# Limite Inferior: -24.28
# Limite Superior: 15.02

# %%
def analyze_distribution_by_covariate(df, metrics_cols, covariate_values):
    """
    Analisa a distribuição dos dados por quartis e outliers para cada métrica,
    separando por tipo de covariável
    
    Parameters:
    df (pandas.DataFrame): DataFrame com os dados
    metrics_cols (list): Lista de colunas de métricas para análise
    covariate_values (list): Lista de valores da coluna Model_covariates para filtrar
    
    Returns:
    dict: Dicionário com as análises por covariável e métrica
    """
    results = {}
    
    for covariate in covariate_values:
        # Filtra o DataFrame para a covariável atual
        df_filtered = df[df['Model_covariates'] == covariate]
        
        results[covariate] = {}
        
        for col in metrics_cols:
            # Calcula os quartis
            Q1 = df_filtered[col].quantile(0.25)
            Q2 = df_filtered[col].quantile(0.50)
            Q3 = df_filtered[col].quantile(0.75)
            
            # Calcula o IQR e os limites para outliers
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            
            # Conta elementos em cada quartil
            first_quartile = df_filtered[(df_filtered[col] >= lower_bound) & 
                                       (df_filtered[col] < Q1)][col].count()
            second_quartile = df_filtered[(df_filtered[col] >= Q1) & 
                                        (df_filtered[col] < Q2)][col].count()
            third_quartile = df_filtered[(df_filtered[col] >= Q2) & 
                                       (df_filtered[col] < Q3)][col].count()
            fourth_quartile = df_filtered[(df_filtered[col] >= Q3) & 
                                        (df_filtered[col] <= upper_bound)][col].count()
            
            # Conta outliers
            outliers_low = df_filtered[df_filtered[col] < lower_bound][col].count()
            outliers_high = df_filtered[df_filtered[col] > upper_bound][col].count()
            
            results[covariate][col] = {
                'Primeiro Quartil': first_quartile,
                'Segundo Quartil': second_quartile,
                'Terceiro Quartil': third_quartile,
                'Quarto Quartil': fourth_quartile,
                'Outliers Negativos': outliers_low,
                'Outliers Positivos': outliers_high,
                'Limites': {
                    'Q1': Q1,
                    'Q2 (Mediana)': Q2,
                    'Q3': Q3,
                    'Limite Inferior': lower_bound,
                    'Limite Superior': upper_bound
                }
            }
    
    return results

# Lista de covariáveis
covariaveis = ['month', 'precipType', 'holiday', 'hour', 
               'dayofweek_num', 'bool_weather_missing_values']

# Lista de métricas
metricas = ["MAE_pct", "SMAPE_pct", "RMSE_pct"]

# Usando a função
resultados = analyze_distribution_by_covariate(df, metricas, covariaveis)

# Imprimindo os resultados de forma organizada
for covariavel, metricas_dict in resultados.items():
    print(f"\nAnálise para covariável: {covariavel}")
    print("=" * 70)
    
    for metrica, dados in metricas_dict.items():
        print(f"\nMétrica: {metrica}")
        print("-" * 50)
        print(f"Distribuição por quartis:")
        print(f"1º Quartil: {dados['Primeiro Quartil']} elementos")
        print(f"2º Quartil: {dados['Segundo Quartil']} elementos")
        print(f"3º Quartil: {dados['Terceiro Quartil']} elementos")
        print(f"4º Quartil: {dados['Quarto Quartil']} elementos")
        print(f"\nOutliers:")
        print(f"Negativos: {dados['Outliers Negativos']} elementos")
        print(f"Positivos: {dados['Outliers Positivos']} elementos")
        print(f"\nLimites:")
        for nome, valor in dados['Limites'].items():
            print(f"{nome}: {valor:.2f}")
# Out:
# Análise para covariável: month
# ======================================================================
#
# Métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 14 elementos
# 2º Quartil: 19 elementos
# 3º Quartil: 21 elementos
# 4º Quartil: 18 elementos
#
# Outliers:
# Negativos: 7 elementos
# Positivos: 3 elementos
#
# Limites:
# Q1: -4.49
# Q2 (Mediana): 0.00
# Q3: 3.73
# Limite Inferior: -16.82
# Limite Superior: 16.05
#
# Métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 16 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 18 elementos
#
# Outliers:
# Negativos: 5 elementos
# Positivos: 3 elementos
#
# Limites:
# Q1: -7.99
# Q2 (Mediana): -0.12
# Q3: 3.17
# Limite Inferior: -24.74
# Limite Superior: 19.91
#
# Métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 11 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 16 elementos
#
# Outliers:
# Negativos: 10 elementos
# Positivos: 5 elementos
#
# Limites:
# Q1: -3.76
# Q2 (Mediana): -0.57
# Q3: 2.52
# Limite Inferior: -13.18
# Limite Superior: 11.94
#
# Análise para covariável: precipType
# ======================================================================
#
# Métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 10 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 17 elementos
#
# Outliers:
# Negativos: 10 elementos
# Positivos: 3 elementos
#
# Limites:
# Q1: -8.34
# Q2 (Mediana): -1.31
# Q3: 1.13
# Limite Inferior: -22.53
# Limite Superior: 15.33
#
# Métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 15 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 19 elementos
#
# Outliers:
# Negativos: 5 elementos
# Positivos: 1 elementos
#
# Limites:
# Q1: -10.07
# Q2 (Mediana): -0.90
# Q3: 2.24
# Limite Inferior: -28.54
# Limite Superior: 20.71
#
# Métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 11 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 18 elementos
#
# Outliers:
# Negativos: 9 elementos
# Positivos: 2 elementos
#
# Limites:
# Q1: -6.51
# Q2 (Mediana): -0.62
# Q3: 1.69
# Limite Inferior: -18.81
# Limite Superior: 13.99
#
# Análise para covariável: holiday
# ======================================================================
#
# Métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 13 elementos
# 2º Quartil: 19 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 19 elementos
#
# Outliers:
# Negativos: 7 elementos
# Positivos: 1 elementos
#
# Limites:
# Q1: -9.88
# Q2 (Mediana): -2.56
# Q3: 1.46
# Limite Inferior: -26.90
# Limite Superior: 18.48
#
# Métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 16 elementos
# 2º Quartil: 19 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 17 elementos
#
# Outliers:
# Negativos: 4 elementos
# Positivos: 3 elementos
#
# Limites:
# Q1: -13.24
# Q2 (Mediana): -2.14
# Q3: 2.52
# Limite Inferior: -36.89
# Limite Superior: 26.17
#
# Métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 13 elementos
# 2º Quartil: 19 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 17 elementos
#
# Outliers:
# Negativos: 7 elementos
# Positivos: 3 elementos
#
# Limites:
# Q1: -9.14
# Q2 (Mediana): -2.17
# Q3: 0.84
# Limite Inferior: -24.12
# Limite Superior: 15.82
#
# Análise para covariável: hour
# ======================================================================
#
# Métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 20 elementos
# 2º Quartil: 21 elementos
# 3º Quartil: 21 elementos
# 4º Quartil: 22 elementos
#
# Outliers:
# Negativos: 1 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -24.16
# Q2 (Mediana): -14.73
# Q3: -6.31
# Limite Inferior: -50.94
# Limite Superior: 20.47
#
# Métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 18 elementos
# 2º Quartil: 21 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 23 elementos
#
# Outliers:
# Negativos: 3 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -23.68
# Q2 (Mediana): -14.94
# Q3: -6.14
# Limite Inferior: -49.99
# Limite Superior: 20.17
#
# Métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 19 elementos
# 2º Quartil: 21 elementos
# 3º Quartil: 21 elementos
# 4º Quartil: 22 elementos
#
# Outliers:
# Negativos: 2 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -18.26
# Q2 (Mediana): -12.00
# Q3: -2.88
# Limite Inferior: -41.33
# Limite Superior: 20.19
#
# Análise para covariável: dayofweek_num
# ======================================================================
#
# Métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 21 elementos
# 2º Quartil: 21 elementos
# 3º Quartil: 21 elementos
# 4º Quartil: 21 elementos
#
# Outliers:
# Negativos: 0 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -20.02
# Q2 (Mediana): -4.71
# Q3: 1.33
# Limite Inferior: -52.06
# Limite Superior: 33.37
#
# Métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 19 elementos
# 2º Quartil: 21 elementos
# 3º Quartil: 21 elementos
# 4º Quartil: 21 elementos
#
# Outliers:
# Negativos: 2 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -18.39
# Q2 (Mediana): -7.89
# Q3: 0.61
# Limite Inferior: -46.90
# Limite Superior: 29.12
#
# Métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 21 elementos
# 2º Quartil: 21 elementos
# 3º Quartil: 21 elementos
# 4º Quartil: 21 elementos
#
# Outliers:
# Negativos: 0 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -16.85
# Q2 (Mediana): -3.21
# Q3: 0.44
# Limite Inferior: -42.79
# Limite Superior: 26.38
#
# Análise para covariável: bool_weather_missing_values
# ======================================================================
#
# Métrica: MAE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 15 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 19 elementos
#
# Outliers:
# Negativos: 5 elementos
# Positivos: 1 elementos
#
# Limites:
# Q1: -11.91
# Q2 (Mediana): -2.00
# Q3: 0.48
# Limite Inferior: -30.51
# Limite Superior: 19.08
#
# Métrica: SMAPE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 17 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 20 elementos
#
# Outliers:
# Negativos: 3 elementos
# Positivos: 0 elementos
#
# Limites:
# Q1: -13.94
# Q2 (Mediana): -3.35
# Q3: 0.48
# Limite Inferior: -35.57
# Limite Superior: 22.11
#
# Métrica: RMSE_pct
# --------------------------------------------------
# Distribuição por quartis:
# 1º Quartil: 14 elementos
# 2º Quartil: 20 elementos
# 3º Quartil: 20 elementos
# 4º Quartil: 18 elementos
#
# Outliers:
# Negativos: 6 elementos
# Positivos: 2 elementos
#
# Limites:
# Q1: -8.74
# Q2 (Mediana): -1.62
# Q3: 1.15
# Limite Inferior: -23.58
# Limite Superior: 15.98

# %%
def results_to_dataframe(results):
    """
    Converte os resultados para um DataFrame mais organizado incluindo
    contagem de elementos antes e depois da mediana
    """
    data = []
    
    for covariavel, metricas in results.items():
        for metrica, dados in metricas.items():
            # Calcula elementos antes e depois da mediana
            antes_mediana = dados['Primeiro Quartil'] + dados['Segundo Quartil'] + dados['Outliers Negativos']
            depois_mediana = dados['Terceiro Quartil'] + dados['Quarto Quartil'] + dados['Outliers Positivos']
            
            row = {
                'Covariável': covariavel,
                'Métrica': metrica,
                'Primeiro Quartil': dados['Primeiro Quartil'],
                'Segundo Quartil': dados['Segundo Quartil'],
                'Terceiro Quartil': dados['Terceiro Quartil'],
                'Quarto Quartil': dados['Quarto Quartil'],
                'Elementos Antes Mediana': antes_mediana,
                'Elementos Depois Mediana': depois_mediana,
                'Outliers Negativos': dados['Outliers Negativos'],
                'Outliers Positivos': dados['Outliers Positivos']
            }
            # Adiciona os limites
            for nome, valor in dados['Limites'].items():
                row[nome] = valor
            data.append(row)
    
    df = pd.DataFrame(data)
    
    # Reordenando as colunas para melhor visualização
    column_order = [
        'Covariável', 'Métrica',
        'Elementos Antes Mediana', 'Elementos Depois Mediana',
        'Primeiro Quartil', 'Segundo Quartil', 
        'Terceiro Quartil', 'Quarto Quartil',
        'Outliers Negativos', 'Outliers Positivos',
        'Q1', 'Q2 (Mediana)', 'Q3',
        'Limite Inferior', 'Limite Superior'
    ]
    
    return df[column_order]

# Usando a função
df_resultados = results_to_dataframe(resultados)

pd.set_option('display.float_format', lambda x: '%.2f' % x)


df_resultados
# Out:
#                      Covariável    Métrica  Elementos Antes Mediana  \
# 0                         month    MAE_pct                       40
# 1                         month  SMAPE_pct                       41
# 2                         month   RMSE_pct                       41
# 3                    precipType    MAE_pct                       40
# 4                    precipType  SMAPE_pct                       40
# 5                    precipType   RMSE_pct                       40
# 6                       holiday    MAE_pct                       39
# 7                       holiday  SMAPE_pct                       39
# 8                       holiday   RMSE_pct                       39
# 9                          hour    MAE_pct                       42
# 10                         hour  SMAPE_pct                       42
# 11                         hour   RMSE_pct                       42
# 12                dayofweek_num    MAE_pct                       42
# 13                dayofweek_num  SMAPE_pct                       42
# 14                dayofweek_num   RMSE_pct                       42
# 15  bool_weather_missing_values    MAE_pct                       40
# 16  bool_weather_missing_values  SMAPE_pct                       40
# 17  bool_weather_missing_values   RMSE_pct                       40
#
#     Elementos Depois Mediana  Primeiro Quartil  Segundo Quartil  \
# 0                         42                14               19
# 1                         41                16               20
# 2                         41                11               20
# 3                         40                10               20
# 4                         40                15               20
# 5                         40                11               20
# 6                         40                13               19
# 7                         40                16               19
# 8                         40                13               19
# 9                         43                20               21
# 10                        43                18               21
# 11                        43                19               21
# 12                        42                21               21
# 13                        42                19               21
# 14                        42                21               21
# 15                        40                15               20
# 16                        40                17               20
# 17                        40                14               20
#
#     Terceiro Quartil  Quarto Quartil  Outliers Negativos  Outliers Positivos  \
# 0                 21              18                   7                   3
# 1                 20              18                   5                   3
# 2                 20              16                  10                   5
# 3                 20              17                  10                   3
# 4                 20              19                   5                   1
# 5                 20              18                   9                   2
# 6                 20              19                   7                   1
# 7                 20              17                   4                   3
# 8                 20              17                   7                   3
# 9                 21              22                   1                   0
# 10                20              23                   3                   0
# 11                21              22                   2                   0
# 12                21              21                   0                   0
# 13                21              21                   2                   0
# 14                21              21                   0                   0
# 15                20              19                   5                   1
# 16                20              20                   3                   0
# 17                20              18                   6                   2
#
#        Q1  Q2 (Mediana)    Q3  Limite Inferior  Limite Superior
# 0   -4.49          0.00  3.73           -16.82            16.05
# 1   -7.99         -0.12  3.17           -24.74            19.91
# 2   -3.76         -0.57  2.52           -13.18            11.94
# 3   -8.34         -1.31  1.13           -22.53            15.33
# 4  -10.07         -0.90  2.24           -28.54            20.71
# 5   -6.51         -0.62  1.69           -18.81            13.99
# 6   -9.88         -2.56  1.46           -26.90            18.48
# 7  -13.24         -2.14  2.52           -36.89            26.17
# 8   -9.14         -2.17  0.84           -24.12            15.82
# 9  -24.16        -14.73 -6.31           -50.94            20.47
# 10 -23.68        -14.94 -6.14           -49.99            20.17
# 11 -18.26        -12.00 -2.88           -41.33            20.19
# 12 -20.02         -4.71  1.33           -52.06            33.37
# 13 -18.39         -7.89  0.61           -46.90            29.12
# 14 -16.85         -3.21  0.44           -42.79            26.38
# 15 -11.91         -2.00  0.48           -30.51            19.08
# 16 -13.94         -3.35  0.48           -35.57            22.11
# 17  -8.74         -1.62  1.15           -23.58            15.98

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Lista de covariáveis
covariaveis = ['month', 'precipType', 'holiday', 'hour', 
               'dayofweek_num', 'bool_weather_missing_values']

# Configurando o subplot
fig, axes = plt.subplots(2, 3, figsize=(20, 15))
sns.set_style("whitegrid")

# Flatten axes para iteração mais fácil
axes_flat = axes.flatten()

# Criando um plot para cada covariável
for idx, covar in enumerate(covariaveis):
    # Filtrando dados para a covariável atual
    df_filtered = df[df['Model_covariates'] == covar]
    
    # Criando o boxplot
    sns.boxplot(data=df_filtered[["MAE_pct", "SMAPE_pct", "RMSE_pct"]].rename(columns = {"MAE_pct":"MAE","SMAPE_pct":"SMAPE","RMSE_pct":"RMSE"}),
                palette="Blues",
                width=0.6,
                showfliers=False,
                ax=axes_flat[idx])
    
    # Adicionando os pontos
    sns.swarmplot(data=df_filtered[["MAE_pct", "SMAPE_pct", "RMSE_pct"]].rename(columns = {"MAE_pct":"MAE","SMAPE_pct":"SMAPE","RMSE_pct":"RMSE"}),
                  color='red',
                  alpha=0.2,
                  size=4,
                  ax=axes_flat[idx])
    
    nome_correto = {'month':'Month', 'precipType':"Precipitation", 'holiday' : "Holiday", 'hour':"Hour", 
               'dayofweek_num':"Day of Week", 'bool_weather_missing_values':"Boolean Weather Missing Value"}

    # Personalizando cada subplot
    axes_flat[idx].set_title(f"{nome_correto[covar]}",
                            fontsize=26,
                            pad=10)
    axes_flat[idx].set_ylabel("Avaliation Metrics Variation (%)",
                             fontsize=14)
    axes_flat[idx].set_xlabel(" \n ",
                             fontsize=12)
    axes_flat[idx].tick_params(axis='x', labelsize=18)
    axes_flat[idx].tick_params(axis='y', labelsize=18)
    # Ajustando os limites do eixo y
    axes_flat[idx].set_ylim(-60, 60)
    
    # Configurando a grade
    axes_flat[idx].yaxis.grid(True, linestyle='--', alpha=0.7)
    axes_flat[idx].xaxis.grid(False)
    
    # Removendo bordas
    sns.despine(ax=axes_flat[idx], left=False, bottom=False)

# Ajustando o título geral
#fig.suptitle("Covariates GRU Models Results",
#             fontsize=18,
#             y=1.02)

# Ajustando o layout
plt.tight_layout()
plt.savefig('GRU_variacao_percentual_covariaveis.png')
plt.show()

# %%
import pandas as pd
import numpy as np

def create_metrics_table(df):
    # Lista de covariáveis na ordem desejada
    covariaveis = ['month', 'precipType', 'holiday', 'hour', 
                   'dayofweek_num', 'bool_weather_missing_values']
    
    # Dicionário para nomes corretos
    nome_correto = {
        'month': 'Month',
        'precipType': 'Precipitation',
        'holiday': 'Holiday',
        'hour': 'Hour',
        'dayofweek_num': 'Day of Week',
        'bool_weather_missing_values': 'Boolean Weather Missing Value'
    }
    
    # Lista para armazenar os resultados
    results = []
    
    # Para cada covariável, calcular as estatísticas
    for covar in covariaveis:
        df_filtered = df[df['Model_covariates'] == covar]
        
        # Calcular estatísticas para cada métrica
        metrics = ['MAE_pct', 'SMAPE_pct', 'RMSE_pct']
        for metric in metrics:
            stats = {
                'Covariate': nome_correto[covar],
                'Metric': metric.replace('_pct', ''),
                'Mean': df_filtered[metric].mean(),
                'Median': df_filtered[metric].median(),
                'Std': df_filtered[metric].std(),
                'Q1': df_filtered[metric].quantile(0.25),
                'Q3': df_filtered[metric].quantile(0.75)
            }
            results.append(stats)
    
    # Criar DataFrame com os resultados
    results_df = pd.DataFrame(results)
    
    # Formatar os números
    numeric_columns = ['Mean', 'Median', 'Std', 'Q1', 'Q3']
    results_df[numeric_columns] = results_df[numeric_columns].round(2)
    
    # Organizar a tabela para melhor visualização
    table = pd.pivot_table(
        results_df,
        values=['Mean', 'Median', 'Std', 'Q1', 'Q3'],
        index=['Covariate', 'Metric'],
        aggfunc='first'
    )
    
    # Adicionar estilo à tabela
    styled_table = table.style\
        .format("{:.2f}")\
        .set_properties(**{'text-align': 'center'})\
        .set_table_styles([
            {'selector': 'th', 'props': [('text-align', 'center'),
                                       ('font-weight', 'bold'),
                                       ('background-color', '#f0f0f0')]},
            {'selector': 'td', 'props': [('text-align', 'center')]},
        ])
    
    return styled_table

# %%
# Para usar a função:
styled_table = create_metrics_table(df)
display(styled_table)
# Out:
# <style type="text/css">
# #T_6ac8a th {
#   text-align: center;
#   font-weight: bold;
#   background-color: #f0f0f0;
# }
# #T_6ac8a td {
#   text-align: center;
# }
# #T_6ac8a_row0_col0, #T_6ac8a_row0_col1, #T_6ac8a_row0_col2, #T_6ac8a_row0_col3, #T_6ac8a_row0_col4, #T_6ac8a_row1_col0, #T_6ac8a_row1_col1, #T_6ac8a_row1_col2, #T_6ac8a_row1_col3, #T_6ac8a_row1_col4, #T_6ac8a_row2_col0, #T_6ac8a_row2_col1, #T_6ac8a_row2_col2, #T_6ac8a_row2_col3, #T_6ac8a_row2_col4, #T_6ac8a_row3_col0, #T_6ac8a_row3_col1, #T_6ac8a_row3_col2, #T_6ac8a_row3_col3, #T_6ac8a_row3_col4, #T_6ac8a_row4_col0, #T_6ac8a_row4_col1, #T_6ac8a_row4_col2, #T_6ac8a_row4_col3, #T_6ac8a_row4_col4, #T_6ac8a_row5_col0, #T_6ac8a_row5_col1, #T_6ac8a_row5_col2, #T_6ac8a_row5_col3, #T_6ac8a_row5_col4, #T_6ac8a_row6_col0, #T_6ac8a_row6_col1, #T_6ac8a_row6_col2, #T_6ac8a_row6_col3, #T_6ac8a_row6_col4, #T_6ac8a_row7_col0, #T_6ac8a_row7_col1, #T_6ac8a_row7_col2, #T_6ac8a_row7_col3, #T_6ac8a_row7_col4, #T_6ac8a_row8_col0, #T_6ac8a_row8_col1, #T_6ac8a_row8_col2, #T_6ac8a_row8_col3, #T_6ac8a_row8_col4, #T_6ac8a_row9_col0, #T_6ac8a_row9_col1, #T_6ac8a_row9_col2, #T_6ac8a_row9_col3, #T_6ac8a_row9_col4, #T_6ac8a_row10_col0, #T_6ac8a_row10_col1, #T_6ac8a_row10_col2, #T_6ac8a_row10_col3, #T_6ac8a_row10_col4, #T_6ac8a_row11_col0, #T_6ac8a_row11_col1, #T_6ac8a_row11_col2, #T_6ac8a_row11_col3, #T_6ac8a_row11_col4, #T_6ac8a_row12_col0, #T_6ac8a_row12_col1, #T_6ac8a_row12_col2, #T_6ac8a_row12_col3, #T_6ac8a_row12_col4, #T_6ac8a_row13_col0, #T_6ac8a_row13_col1, #T_6ac8a_row13_col2, #T_6ac8a_row13_col3, #T_6ac8a_row13_col4, #T_6ac8a_row14_col0, #T_6ac8a_row14_col1, #T_6ac8a_row14_col2, #T_6ac8a_row14_col3, #T_6ac8a_row14_col4, #T_6ac8a_row15_col0, #T_6ac8a_row15_col1, #T_6ac8a_row15_col2, #T_6ac8a_row15_col3, #T_6ac8a_row15_col4, #T_6ac8a_row16_col0, #T_6ac8a_row16_col1, #T_6ac8a_row16_col2, #T_6ac8a_row16_col3, #T_6ac8a_row16_col4, #T_6ac8a_row17_col0, #T_6ac8a_row17_col1, #T_6ac8a_row17_col2, #T_6ac8a_row17_col3, #T_6ac8a_row17_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_6ac8a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ac8a_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_6ac8a_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_6ac8a_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_6ac8a_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_6ac8a_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Covariate</th>
#       <th class="index_name level1" >Metric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ac8a_level0_row0" class="row_heading level0 row0" rowspan="3">Boolean Weather Missing Value</th>
#       <th id="T_6ac8a_level1_row0" class="row_heading level1 row0" >MAE</th>
#       <td id="T_6ac8a_row0_col0" class="data row0 col0" >-6.70</td>
#       <td id="T_6ac8a_row0_col1" class="data row0 col1" >-2.00</td>
#       <td id="T_6ac8a_row0_col2" class="data row0 col2" >-11.91</td>
#       <td id="T_6ac8a_row0_col3" class="data row0 col3" >0.48</td>
#       <td id="T_6ac8a_row0_col4" class="data row0 col4" >12.77</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row1" class="row_heading level1 row1" >RMSE</th>
#       <td id="T_6ac8a_row1_col0" class="data row1 col0" >-5.44</td>
#       <td id="T_6ac8a_row1_col1" class="data row1 col1" >-1.62</td>
#       <td id="T_6ac8a_row1_col2" class="data row1 col2" >-8.74</td>
#       <td id="T_6ac8a_row1_col3" class="data row1 col3" >1.15</td>
#       <td id="T_6ac8a_row1_col4" class="data row1 col4" >11.77</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row2" class="row_heading level1 row2" >SMAPE</th>
#       <td id="T_6ac8a_row2_col0" class="data row2 col0" >-6.79</td>
#       <td id="T_6ac8a_row2_col1" class="data row2 col1" >-3.35</td>
#       <td id="T_6ac8a_row2_col2" class="data row2 col2" >-13.94</td>
#       <td id="T_6ac8a_row2_col3" class="data row2 col3" >0.48</td>
#       <td id="T_6ac8a_row2_col4" class="data row2 col4" >13.18</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level0_row3" class="row_heading level0 row3" rowspan="3">Day of Week</th>
#       <th id="T_6ac8a_level1_row3" class="row_heading level1 row3" >MAE</th>
#       <td id="T_6ac8a_row3_col0" class="data row3 col0" >-8.34</td>
#       <td id="T_6ac8a_row3_col1" class="data row3 col1" >-4.70</td>
#       <td id="T_6ac8a_row3_col2" class="data row3 col2" >-20.02</td>
#       <td id="T_6ac8a_row3_col3" class="data row3 col3" >1.33</td>
#       <td id="T_6ac8a_row3_col4" class="data row3 col4" >13.36</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row4" class="row_heading level1 row4" >RMSE</th>
#       <td id="T_6ac8a_row4_col0" class="data row4 col0" >-7.58</td>
#       <td id="T_6ac8a_row4_col1" class="data row4 col1" >-3.22</td>
#       <td id="T_6ac8a_row4_col2" class="data row4 col2" >-16.85</td>
#       <td id="T_6ac8a_row4_col3" class="data row4 col3" >0.44</td>
#       <td id="T_6ac8a_row4_col4" class="data row4 col4" >11.96</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row5" class="row_heading level1 row5" >SMAPE</th>
#       <td id="T_6ac8a_row5_col0" class="data row5 col0" >-8.78</td>
#       <td id="T_6ac8a_row5_col1" class="data row5 col1" >-7.89</td>
#       <td id="T_6ac8a_row5_col2" class="data row5 col2" >-18.40</td>
#       <td id="T_6ac8a_row5_col3" class="data row5 col3" >0.61</td>
#       <td id="T_6ac8a_row5_col4" class="data row5 col4" >14.78</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level0_row6" class="row_heading level0 row6" rowspan="3">Holiday</th>
#       <th id="T_6ac8a_level1_row6" class="row_heading level1 row6" >MAE</th>
#       <td id="T_6ac8a_row6_col0" class="data row6 col0" >-4.83</td>
#       <td id="T_6ac8a_row6_col1" class="data row6 col1" >-2.56</td>
#       <td id="T_6ac8a_row6_col2" class="data row6 col2" >-9.88</td>
#       <td id="T_6ac8a_row6_col3" class="data row6 col3" >1.46</td>
#       <td id="T_6ac8a_row6_col4" class="data row6 col4" >19.04</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row7" class="row_heading level1 row7" >RMSE</th>
#       <td id="T_6ac8a_row7_col0" class="data row7 col0" >-4.05</td>
#       <td id="T_6ac8a_row7_col1" class="data row7 col1" >-2.17</td>
#       <td id="T_6ac8a_row7_col2" class="data row7 col2" >-9.14</td>
#       <td id="T_6ac8a_row7_col3" class="data row7 col3" >0.84</td>
#       <td id="T_6ac8a_row7_col4" class="data row7 col4" >15.12</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row8" class="row_heading level1 row8" >SMAPE</th>
#       <td id="T_6ac8a_row8_col0" class="data row8 col0" >-3.44</td>
#       <td id="T_6ac8a_row8_col1" class="data row8 col1" >-2.14</td>
#       <td id="T_6ac8a_row8_col2" class="data row8 col2" >-13.24</td>
#       <td id="T_6ac8a_row8_col3" class="data row8 col3" >2.52</td>
#       <td id="T_6ac8a_row8_col4" class="data row8 col4" >22.28</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level0_row9" class="row_heading level0 row9" rowspan="3">Hour</th>
#       <th id="T_6ac8a_level1_row9" class="row_heading level1 row9" >MAE</th>
#       <td id="T_6ac8a_row9_col0" class="data row9 col0" >-15.87</td>
#       <td id="T_6ac8a_row9_col1" class="data row9 col1" >-14.73</td>
#       <td id="T_6ac8a_row9_col2" class="data row9 col2" >-24.16</td>
#       <td id="T_6ac8a_row9_col3" class="data row9 col3" >-6.31</td>
#       <td id="T_6ac8a_row9_col4" class="data row9 col4" >13.26</td>
#     </tr>
#     <tr>
#       <th id="T_6ac8a_level1_row10" class="row_heading level1 row10" >RMSE</th>
#       <td id="T_6ac8a_row10_col0" class="data row10 col0" >-12.68</td>
#       <td id="T_6ac8a_row10_col1" class="data row10 col1" >-12.00</td>
#       <td id="T_6ac8a_row10_col2" class="data row10 col2" >-18.26</td>
#       <td id="T_6ac8a_row10_col3" class="data

# %%
def create_metrics_table_(df):
    # Lista de covariáveis na ordem desejada
    covariaveis = ['month', 'precipType', 'holiday', 'hour', 
                   'dayofweek_num', 'bool_weather_missing_values']
    
    # Dicionário para nomes corretos
    nome_correto = {
        'month': 'Month',
        'precipType': 'Precipitation',
        'holiday': 'Holiday',
        'hour': 'Hour',
        'dayofweek_num': 'Day of Week',
        'bool_weather_missing_values': 'Boolean Weather Missing Value'
    }
    
    # Lista para armazenar os resultados
    results = []
    
    # Para cada covariável, calcular as estatísticas
    for covar in covariaveis:
        df_filtered = df[df['Model_covariates'] == covar]
        
        # Calcular estatísticas para cada métrica
        metrics = ['MAE_pct', 'SMAPE_pct', 'RMSE_pct']
        for metric in metrics:
            stats = {
                'Metric': metric.replace('_pct', ''),
                'Covariate': nome_correto[covar],
                'Mean': df_filtered[metric].mean(),
                'Median': df_filtered[metric].median(),
                'Std': df_filtered[metric].std(),
                'Q1': df_filtered[metric].quantile(0.25),
                'Q3': df_filtered[metric].quantile(0.75)
            }
            results.append(stats)
    
    # Criar DataFrame com os resultados
    results_df = pd.DataFrame(results)
    
    # Formatar os números
    numeric_columns = ['Mean', 'Median', 'Std', 'Q1', 'Q3']
    results_df[numeric_columns] = results_df[numeric_columns].round(2)
    
    # Organizar a tabela para melhor visualização
    # Nota: Invertemos a ordem dos índices aqui
    table = pd.pivot_table(
        results_df,
        values=['Mean', 'Median', 'Std', 'Q1', 'Q3'],
        index=['Metric', 'Covariate'],  # Métrica primeiro, depois covariável
        aggfunc='first'
    )
    
    # Adicionar estilo à tabela
    styled_table = table.style\
        .format("{:.2f}")\
        .set_properties(**{'text-align': 'center'})\
        .set_table_styles([
            {'selector': 'th', 'props': [('text-align', 'center'),
                                       ('font-weight', 'bold'),
                                       ('background-color', '#f0f0f0')]},
            {'selector': 'td', 'props': [('text-align', 'center')]},
            {'selector': '', 'props': [('border', '1px solid #ddd')]},
            {'selector': 'tbody tr:nth-of-type(odd)', 'props': [('background-color', '#f9f9f9')]},
        ])
    
    return styled_table

# %%
styled_table_ = create_metrics_table_(df)
#display(styled_table_)
styled_table_
# Out:
# <style type="text/css">
# #T_5efae th {
#   text-align: center;
#   font-weight: bold;
#   background-color: #f0f0f0;
# }
# #T_5efae td {
#   text-align: center;
# }
# #T_5efae  {
#   border: 1px solid #ddd;
# }
# #T_5efae tbody tr:nth-of-type(odd) {
#   background-color: #f9f9f9;
# }
# #T_5efae_row0_col0, #T_5efae_row0_col1, #T_5efae_row0_col2, #T_5efae_row0_col3, #T_5efae_row0_col4, #T_5efae_row1_col0, #T_5efae_row1_col1, #T_5efae_row1_col2, #T_5efae_row1_col3, #T_5efae_row1_col4, #T_5efae_row2_col0, #T_5efae_row2_col1, #T_5efae_row2_col2, #T_5efae_row2_col3, #T_5efae_row2_col4, #T_5efae_row3_col0, #T_5efae_row3_col1, #T_5efae_row3_col2, #T_5efae_row3_col3, #T_5efae_row3_col4, #T_5efae_row4_col0, #T_5efae_row4_col1, #T_5efae_row4_col2, #T_5efae_row4_col3, #T_5efae_row4_col4, #T_5efae_row5_col0, #T_5efae_row5_col1, #T_5efae_row5_col2, #T_5efae_row5_col3, #T_5efae_row5_col4, #T_5efae_row6_col0, #T_5efae_row6_col1, #T_5efae_row6_col2, #T_5efae_row6_col3, #T_5efae_row6_col4, #T_5efae_row7_col0, #T_5efae_row7_col1, #T_5efae_row7_col2, #T_5efae_row7_col3, #T_5efae_row7_col4, #T_5efae_row8_col0, #T_5efae_row8_col1, #T_5efae_row8_col2, #T_5efae_row8_col3, #T_5efae_row8_col4, #T_5efae_row9_col0, #T_5efae_row9_col1, #T_5efae_row9_col2, #T_5efae_row9_col3, #T_5efae_row9_col4, #T_5efae_row10_col0, #T_5efae_row10_col1, #T_5efae_row10_col2, #T_5efae_row10_col3, #T_5efae_row10_col4, #T_5efae_row11_col0, #T_5efae_row11_col1, #T_5efae_row11_col2, #T_5efae_row11_col3, #T_5efae_row11_col4, #T_5efae_row12_col0, #T_5efae_row12_col1, #T_5efae_row12_col2, #T_5efae_row12_col3, #T_5efae_row12_col4, #T_5efae_row13_col0, #T_5efae_row13_col1, #T_5efae_row13_col2, #T_5efae_row13_col3, #T_5efae_row13_col4, #T_5efae_row14_col0, #T_5efae_row14_col1, #T_5efae_row14_col2, #T_5efae_row14_col3, #T_5efae_row14_col4, #T_5efae_row15_col0, #T_5efae_row15_col1, #T_5efae_row15_col2, #T_5efae_row15_col3, #T_5efae_row15_col4, #T_5efae_row16_col0, #T_5efae_row16_col1, #T_5efae_row16_col2, #T_5efae_row16_col3, #T_5efae_row16_col4, #T_5efae_row17_col0, #T_5efae_row17_col1, #T_5efae_row17_col2, #T_5efae_row17_col3, #T_5efae_row17_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_5efae">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5efae_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_5efae_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_5efae_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_5efae_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_5efae_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th class="index_name level1" >Covariate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5efae_level0_row0" class="row_heading level0 row0" rowspan="6">MAE</th>
#       <th id="T_5efae_level1_row0" class="row_heading level1 row0" >Boolean Weather Missing Value</th>
#       <td id="T_5efae_row0_col0" class="data row0 col0" >-6.70</td>
#       <td id="T_5efae_row0_col1" class="data row0 col1" >-2.00</td>
#       <td id="T_5efae_row0_col2" class="data row0 col2" >-11.91</td>
#       <td id="T_5efae_row0_col3" class="data row0 col3" >0.48</td>
#       <td id="T_5efae_row0_col4" class="data row0 col4" >12.77</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row1" class="row_heading level1 row1" >Day of Week</th>
#       <td id="T_5efae_row1_col0" class="data row1 col0" >-8.34</td>
#       <td id="T_5efae_row1_col1" class="data row1 col1" >-4.70</td>
#       <td id="T_5efae_row1_col2" class="data row1 col2" >-20.02</td>
#       <td id="T_5efae_row1_col3" class="data row1 col3" >1.33</td>
#       <td id="T_5efae_row1_col4" class="data row1 col4" >13.36</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row2" class="row_heading level1 row2" >Holiday</th>
#       <td id="T_5efae_row2_col0" class="data row2 col0" >-4.83</td>
#       <td id="T_5efae_row2_col1" class="data row2 col1" >-2.56</td>
#       <td id="T_5efae_row2_col2" class="data row2 col2" >-9.88</td>
#       <td id="T_5efae_row2_col3" class="data row2 col3" >1.46</td>
#       <td id="T_5efae_row2_col4" class="data row2 col4" >19.04</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row3" class="row_heading level1 row3" >Hour</th>
#       <td id="T_5efae_row3_col0" class="data row3 col0" >-15.87</td>
#       <td id="T_5efae_row3_col1" class="data row3 col1" >-14.73</td>
#       <td id="T_5efae_row3_col2" class="data row3 col2" >-24.16</td>
#       <td id="T_5efae_row3_col3" class="data row3 col3" >-6.31</td>
#       <td id="T_5efae_row3_col4" class="data row3 col4" >13.26</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row4" class="row_heading level1 row4" >Month</th>
#       <td id="T_5efae_row4_col0" class="data row4 col0" >-1.87</td>
#       <td id="T_5efae_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_5efae_row4_col2" class="data row4 col2" >-4.49</td>
#       <td id="T_5efae_row4_col3" class="data row4 col3" >3.73</td>
#       <td id="T_5efae_row4_col4" class="data row4 col4" >12.71</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row5" class="row_heading level1 row5" >Precipitation</th>
#       <td id="T_5efae_row5_col0" class="data row5 col0" >-4.98</td>
#       <td id="T_5efae_row5_col1" class="data row5 col1" >-1.31</td>
#       <td id="T_5efae_row5_col2" class="data row5 col2" >-8.34</td>
#       <td id="T_5efae_row5_col3" class="data row5 col3" >1.13</td>
#       <td id="T_5efae_row5_col4" class="data row5 col4" >13.49</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level0_row6" class="row_heading level0 row6" rowspan="6">RMSE</th>
#       <th id="T_5efae_level1_row6" class="row_heading level1 row6" >Boolean Weather Missing Value</th>
#       <td id="T_5efae_row6_col0" class="data row6 col0" >-5.44</td>
#       <td id="T_5efae_row6_col1" class="data row6 col1" >-1.62</td>
#       <td id="T_5efae_row6_col2" class="data row6 col2" >-8.74</td>
#       <td id="T_5efae_row6_col3" class="data row6 col3" >1.15</td>
#       <td id="T_5efae_row6_col4" class="data row6 col4" >11.77</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row7" class="row_heading level1 row7" >Day of Week</th>
#       <td id="T_5efae_row7_col0" class="data row7 col0" >-7.58</td>
#       <td id="T_5efae_row7_col1" class="data row7 col1" >-3.22</td>
#       <td id="T_5efae_row7_col2" class="data row7 col2" >-16.85</td>
#       <td id="T_5efae_row7_col3" class="data row7 col3" >0.44</td>
#       <td id="T_5efae_row7_col4" class="data row7 col4" >11.96</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row8" class="row_heading level1 row8" >Holiday</th>
#       <td id="T_5efae_row8_col0" class="data row8 col0" >-4.05</td>
#       <td id="T_5efae_row8_col1" class="data row8 col1" >-2.17</td>
#       <td id="T_5efae_row8_col2" class="data row8 col2" >-9.14</td>
#       <td id="T_5efae_row8_col3" class="data row8 col3" >0.84</td>
#       <td id="T_5efae_row8_col4" class="data row8 col4" >15.12</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row9" class="row_heading level1 row9" >Hour</th>
#       <td id="T_5efae_row9_col0" class="data row9 col0" >-12.68</td>
#       <td id="T_5efae_row9_col1" class="data row9 col1" >-12.00</td>
#       <td id="T_5efae_row9_col2" class="data row9 col2" >-18.26</td>
#       <td id="T_5efae_row9_col3" class="data row9 col3" >-2.88</td>
#       <td id="T_5efae_row9_col4" class="data row9 col4" >12.05</td>
#     </tr>
#     <tr>
#       <th id="T_5efae_level1_row10" class="row_heading level1 row10" >Month</th>
#       <td id="T_5efae_row10_col0" class="data row10 col0" >-1.49</td>
#       <td id="T_5efae_row10_col1" class="data row10 col1" >-0.57</td>
#       <td id="T_5efae_row10_col2" class="data row10 col2" >-3.76</td>
#       <td id="T_5efae_row10_col3" class="data row10 col3" >2.52</td>

# %%
import seaborn as sns
metricas = ['MAE_pct', 'SMAPE_pct', 'RMSE_pct']
nome_metricas = {'MAE_pct': 'MAE', 'SMAPE_pct': 'SMAPE', 'RMSE_pct': 'RMSE'}
nome_correto = {
    'month': 'Month',
    'precipType': "Precipitation",
    'holiday': "Holiday",
    'hour': "Hour",
    'dayofweek_num': "Day of Week",
    'bool_weather_missing_values': "Boolean WMV"
}

# Configurando o subplot
fig, axes = plt.subplots(1, 3, figsize=(24, 8))
sns.set_style("whitegrid")

# Criando um plot para cada métrica
for idx, metrica in enumerate(metricas):
    # Preparando os dados para o boxplot
    plot_data = []
    for covar in nome_correto.keys():
        df_filtered = df[df['Model_covariates'] == covar]
        df_filtered['Covariate'] = nome_correto[covar]
        plot_data.append(df_filtered[['Covariate', metrica]])
    
    plot_df = pd.concat(plot_data)
    
    # Calculando a mediana para cada covariável e ordenando
    medians = plot_df.groupby('Covariate')[metrica].median().sort_values()
    covariate_order = medians.index.tolist()
    
    # Criando o boxplot com a ordem personalizada
    sns.boxplot(
        data=plot_df,
        x='Covariate',
        y=metrica,
        palette="Blues",
        width=0.6,
        showfliers=False,
        order=covariate_order,  # Definindo a ordem baseada na mediana
        ax=axes[idx]
    )
    
    # Adicionando os pontos (mantendo a mesma ordem do boxplot)
    sns.swarmplot(
        data=plot_df,
        x='Covariate',
        y=metrica,
        color='red',
        alpha=0.2,
        size=4,
        order=covariate_order,  # Mesma ordem do boxplot
        ax=axes[idx]
    )
    
    # Personalizando cada subplot
    axes[idx].set_title(f"{nome_metricas[metrica]}",
                       fontsize=26,
                       pad=10)
    axes[idx].set_ylabel("Variation (%)",
                        fontsize=14)
    axes[idx].set_xlabel("",
                        fontsize=12)
    
    # Ajustando os ticks
    axes[idx].tick_params(axis='x', labelsize=20)
    axes[idx].tick_params(axis='y', labelsize=20)
    
    # Rotacionando os labels do eixo x
    plt.setp(axes[idx].get_xticklabels(), rotation=45, ha='right')
    
    # Ajustando os limites do eixo y
    axes[idx].set_ylim(-60, 60)
    
    # Configurando a grade
    axes[idx].yaxis.grid(True, linestyle='--', alpha=0.7)
    axes[idx].xaxis.grid(False)
    
    # Removendo bordas
    sns.despine(ax=axes[idx], left=False, bottom=False)

# Ajustando o layout
plt.tight_layout()

# Salvando a figura
plt.savefig('GRU_metrics_by_covariates_boxplot_ordered.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /home/carlos/anaconda3/envs/tensorflow-park/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Covariate'] = nome_correto[covar]
# /tmp/ipykernel_19367/1712850867.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
def create_metrics_table_(df):
    # Lista de covariáveis na ordem desejada
    covariaveis = ['month', 'precipType', 'holiday', 'hour', 
                   'dayofweek_num', 'bool_weather_missing_values']
    
    # Dicionário para nomes corretos
    nome_correto = {
        'month': 'Month',
        'precipType': 'Precipitation',
        'holiday': 'Holiday',
        'hour': 'Hour',
        'dayofweek_num': 'Day of Week',
        'bool_weather_missing_values': 'Boolean Weather Missing Value'
    }
    
    # Lista para armazenar os resultados
    results = []
    
    # Para cada covariável, calcular as estatísticas
    for covar in covariaveis:
        df_filtered = df[df['Model_covariates'] == covar]
        
        # Calcular estatísticas para cada métrica
        metrics = ['MAE_pct', 'SMAPE_pct', 'RMSE_pct']
        for metric in metrics:
            stats = {
                'Metric': metric.replace('_pct', ''),
                'Covariate': nome_correto[covar],
                'Mean': df_filtered[metric].mean(),
                'Median': df_filtered[metric].median(),
                'Std': df_filtered[metric].std(),
                'Q1': df_filtered[metric].quantile(0.25),
                'Q3': df_filtered[metric].quantile(0.75)
            }
            results.append(stats)
    
    # Criar DataFrame com os resultados
    results_df = pd.DataFrame(results)
    
    # Formatar os números
    numeric_columns = ['Mean', 'Median', 'Std', 'Q1', 'Q3']
    results_df[numeric_columns] = results_df[numeric_columns].round(4)
    
    # Criar um DataFrame pivotado
    table = pd.pivot_table(
        results_df,
        values=['Mean', 'Median', 'Std', 'Q1', 'Q3'],
        index=['Metric', 'Covariate'],
        aggfunc='first'
    )
    
    # Ordenar as covariáveis por mediana dentro de cada métrica
    table_reset = table.reset_index()
    ordered_dfs = []
    
    # Para cada métrica (MAE, SMAPE, RMSE)
    for metric in table_reset['Metric'].unique():
        metric_data = table_reset[table_reset['Metric'] == metric]
        metric_data_sorted = metric_data.sort_values('Median', ascending=True)
        ordered_dfs.append(metric_data_sorted)
    
    # Concatenamos todos os DataFrames ordenados
    final_table = pd.concat(ordered_dfs)
    
    # Recriamos a tabela pivotada com os dados ordenados
    table = final_table.set_index(['Metric', 'Covariate'])
    
    # Criar JSON organizado
    json_data = {}
    for metric in final_table['Metric'].unique():
        metric_data = final_table[final_table['Metric'] == metric]
        json_data[metric] = {}
        
        for _, row in metric_data.iterrows():
            covariate = row['Covariate']
            json_data[metric][covariate] = {
                'mean': round(row['Mean'], 4),
                'median': round(row['Median'], 4),
                'std': round(row['Std'], 4),
                'q1': round(row['Q1'], 4),
                'q3': round(row['Q3'], 4)
            }
    
    # Adicionar estilo à tabela
    styled_table = table.style\
        .format("{:.2f}")\
        .set_properties(**{'text-align': 'center'})\
        .set_table_styles([
            {'selector': 'th', 'props': [('text-align', 'center'),
                                       ('font-weight', 'bold'),
                                       ('background-color', '#f0f0f0')]},
            {'selector': 'td', 'props': [('text-align', 'center')]},
            {'selector': '', 'props': [('border', '1px solid #ddd')]},
            {'selector': 'tbody tr:nth-of-type(odd)', 'props': [('background-color', '#f9f9f9')]},
        ])
    
    return styled_table, json_data

# %%
styled_table_, Json = create_metrics_table_(df)
display(styled_table_)
# Out:
# <style type="text/css">
# #T_9d488 th {
#   text-align: center;
#   font-weight: bold;
#   background-color: #f0f0f0;
# }
# #T_9d488 td {
#   text-align: center;
# }
# #T_9d488  {
#   border: 1px solid #ddd;
# }
# #T_9d488 tbody tr:nth-of-type(odd) {
#   background-color: #f9f9f9;
# }
# #T_9d488_row0_col0, #T_9d488_row0_col1, #T_9d488_row0_col2, #T_9d488_row0_col3, #T_9d488_row0_col4, #T_9d488_row1_col0, #T_9d488_row1_col1, #T_9d488_row1_col2, #T_9d488_row1_col3, #T_9d488_row1_col4, #T_9d488_row2_col0, #T_9d488_row2_col1, #T_9d488_row2_col2, #T_9d488_row2_col3, #T_9d488_row2_col4, #T_9d488_row3_col0, #T_9d488_row3_col1, #T_9d488_row3_col2, #T_9d488_row3_col3, #T_9d488_row3_col4, #T_9d488_row4_col0, #T_9d488_row4_col1, #T_9d488_row4_col2, #T_9d488_row4_col3, #T_9d488_row4_col4, #T_9d488_row5_col0, #T_9d488_row5_col1, #T_9d488_row5_col2, #T_9d488_row5_col3, #T_9d488_row5_col4, #T_9d488_row6_col0, #T_9d488_row6_col1, #T_9d488_row6_col2, #T_9d488_row6_col3, #T_9d488_row6_col4, #T_9d488_row7_col0, #T_9d488_row7_col1, #T_9d488_row7_col2, #T_9d488_row7_col3, #T_9d488_row7_col4, #T_9d488_row8_col0, #T_9d488_row8_col1, #T_9d488_row8_col2, #T_9d488_row8_col3, #T_9d488_row8_col4, #T_9d488_row9_col0, #T_9d488_row9_col1, #T_9d488_row9_col2, #T_9d488_row9_col3, #T_9d488_row9_col4, #T_9d488_row10_col0, #T_9d488_row10_col1, #T_9d488_row10_col2, #T_9d488_row10_col3, #T_9d488_row10_col4, #T_9d488_row11_col0, #T_9d488_row11_col1, #T_9d488_row11_col2, #T_9d488_row11_col3, #T_9d488_row11_col4, #T_9d488_row12_col0, #T_9d488_row12_col1, #T_9d488_row12_col2, #T_9d488_row12_col3, #T_9d488_row12_col4, #T_9d488_row13_col0, #T_9d488_row13_col1, #T_9d488_row13_col2, #T_9d488_row13_col3, #T_9d488_row13_col4, #T_9d488_row14_col0, #T_9d488_row14_col1, #T_9d488_row14_col2, #T_9d488_row14_col3, #T_9d488_row14_col4, #T_9d488_row15_col0, #T_9d488_row15_col1, #T_9d488_row15_col2, #T_9d488_row15_col3, #T_9d488_row15_col4, #T_9d488_row16_col0, #T_9d488_row16_col1, #T_9d488_row16_col2, #T_9d488_row16_col3, #T_9d488_row16_col4, #T_9d488_row17_col0, #T_9d488_row17_col1, #T_9d488_row17_col2, #T_9d488_row17_col3, #T_9d488_row17_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_9d488">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d488_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_9d488_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_9d488_level0_col2" class="col_heading level0 col2" >Q1</th>
#       <th id="T_9d488_level0_col3" class="col_heading level0 col3" >Q3</th>
#       <th id="T_9d488_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th class="index_name level1" >Covariate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d488_level0_row0" class="row_heading level0 row0" rowspan="6">MAE</th>
#       <th id="T_9d488_level1_row0" class="row_heading level1 row0" >Hour</th>
#       <td id="T_9d488_row0_col0" class="data row0 col0" >-15.87</td>
#       <td id="T_9d488_row0_col1" class="data row0 col1" >-14.73</td>
#       <td id="T_9d488_row0_col2" class="data row0 col2" >-24.16</td>
#       <td id="T_9d488_row0_col3" class="data row0 col3" >-6.31</td>
#       <td id="T_9d488_row0_col4" class="data row0 col4" >13.26</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row1" class="row_heading level1 row1" >Day of Week</th>
#       <td id="T_9d488_row1_col0" class="data row1 col0" >-8.34</td>
#       <td id="T_9d488_row1_col1" class="data row1 col1" >-4.71</td>
#       <td id="T_9d488_row1_col2" class="data row1 col2" >-20.02</td>
#       <td id="T_9d488_row1_col3" class="data row1 col3" >1.33</td>
#       <td id="T_9d488_row1_col4" class="data row1 col4" >13.36</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row2" class="row_heading level1 row2" >Holiday</th>
#       <td id="T_9d488_row2_col0" class="data row2 col0" >-4.83</td>
#       <td id="T_9d488_row2_col1" class="data row2 col1" >-2.56</td>
#       <td id="T_9d488_row2_col2" class="data row2 col2" >-9.88</td>
#       <td id="T_9d488_row2_col3" class="data row2 col3" >1.46</td>
#       <td id="T_9d488_row2_col4" class="data row2 col4" >19.04</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row3" class="row_heading level1 row3" >Boolean Weather Missing Value</th>
#       <td id="T_9d488_row3_col0" class="data row3 col0" >-6.70</td>
#       <td id="T_9d488_row3_col1" class="data row3 col1" >-2.00</td>
#       <td id="T_9d488_row3_col2" class="data row3 col2" >-11.91</td>
#       <td id="T_9d488_row3_col3" class="data row3 col3" >0.48</td>
#       <td id="T_9d488_row3_col4" class="data row3 col4" >12.77</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row4" class="row_heading level1 row4" >Precipitation</th>
#       <td id="T_9d488_row4_col0" class="data row4 col0" >-4.98</td>
#       <td id="T_9d488_row4_col1" class="data row4 col1" >-1.31</td>
#       <td id="T_9d488_row4_col2" class="data row4 col2" >-8.34</td>
#       <td id="T_9d488_row4_col3" class="data row4 col3" >1.13</td>
#       <td id="T_9d488_row4_col4" class="data row4 col4" >13.49</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row5" class="row_heading level1 row5" >Month</th>
#       <td id="T_9d488_row5_col0" class="data row5 col0" >-1.87</td>
#       <td id="T_9d488_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_9d488_row5_col2" class="data row5 col2" >-4.49</td>
#       <td id="T_9d488_row5_col3" class="data row5 col3" >3.73</td>
#       <td id="T_9d488_row5_col4" class="data row5 col4" >12.71</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level0_row6" class="row_heading level0 row6" rowspan="6">RMSE</th>
#       <th id="T_9d488_level1_row6" class="row_heading level1 row6" >Hour</th>
#       <td id="T_9d488_row6_col0" class="data row6 col0" >-12.68</td>
#       <td id="T_9d488_row6_col1" class="data row6 col1" >-12.00</td>
#       <td id="T_9d488_row6_col2" class="data row6 col2" >-18.26</td>
#       <td id="T_9d488_row6_col3" class="data row6 col3" >-2.88</td>
#       <td id="T_9d488_row6_col4" class="data row6 col4" >12.05</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row7" class="row_heading level1 row7" >Day of Week</th>
#       <td id="T_9d488_row7_col0" class="data row7 col0" >-7.58</td>
#       <td id="T_9d488_row7_col1" class="data row7 col1" >-3.21</td>
#       <td id="T_9d488_row7_col2" class="data row7 col2" >-16.85</td>
#       <td id="T_9d488_row7_col3" class="data row7 col3" >0.44</td>
#       <td id="T_9d488_row7_col4" class="data row7 col4" >11.96</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row8" class="row_heading level1 row8" >Holiday</th>
#       <td id="T_9d488_row8_col0" class="data row8 col0" >-4.05</td>
#       <td id="T_9d488_row8_col1" class="data row8 col1" >-2.17</td>
#       <td id="T_9d488_row8_col2" class="data row8 col2" >-9.14</td>
#       <td id="T_9d488_row8_col3" class="data row8 col3" >0.84</td>
#       <td id="T_9d488_row8_col4" class="data row8 col4" >15.12</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row9" class="row_heading level1 row9" >Boolean Weather Missing Value</th>
#       <td id="T_9d488_row9_col0" class="data row9 col0" >-5.44</td>
#       <td id="T_9d488_row9_col1" class="data row9 col1" >-1.62</td>
#       <td id="T_9d488_row9_col2" class="data row9 col2" >-8.74</td>
#       <td id="T_9d488_row9_col3" class="data row9 col3" >1.15</td>
#       <td id="T_9d488_row9_col4" class="data row9 col4" >11.77</td>
#     </tr>
#     <tr>
#       <th id="T_9d488_level1_row10" class="row_heading level1 row10" >Precipitation</th>
#       <td id="T_9d488_row10_col0" class="data row10 col0" >-3.34</td>
#       <td id="T_9d488_row10_col1" class="data row10 col1" >-0.62</td>
#       <td id="T_9d488_row10_col2" class="data row10 col2" >-6.51</td>
#       <td id="T_9d488_row10_col3" class="data row10 col3" >1.69<

# %%
from pprint import pprint


pprint(Json)
# Out:
# {'MAE': {'Boolean Weather Missing Value': {'mean': -6.6956,
#                                            'median': -2.005,
#                                            'q1': -11.9125,
#                                            'q3': 0.485,
#                                            'std': 12.7702},
#          'Day of Week': {'mean': -8.3448,
#                          'median': -4.705,
#                          'q1': -20.025,
#                          'q3': 1.3325,
#                          'std': 13.3584},
#          'Holiday': {'mean': -4.8315,
#                      'median': -2.56,
#                      'q1': -9.885,
#                      'q3': 1.46,
#                      'std': 19.0414},
#          'Hour': {'mean': -15.8668,
#                   'median': -14.73,
#                   'q1': -24.16,
#                   'q3': -6.31,
#                   'std': 13.2588},
#          'Month': {'mean': -1.8726,
#                    'median': 0.0,
#                    'q1': -4.49,
#                    'q3': 3.7275,
#                    'std': 12.7082},
#          'Precipitation': {'mean': -4.979,
#                            'median': -1.31,
#                            'q1': -8.335,
#                            'q3': 1.13,
#                            'std': 13.4885}},
#  'RMSE': {'Boolean Weather Missing Value': {'mean': -5.4353,
#                                             'median': -1.62,
#                                             'q1': -8.7425,
#                                             'q3': 1.1475,
#                                             'std': 11.7706},
#           'Day of Week': {'mean': -7.582,
#                           'median': -3.215,
#                           'q1': -16.85,
#                           'q3': 0.44,
#                           'std': 11.959},
#           'Holiday': {'mean': -4.0544,
#                       'median': -2.17,
#                       'q1': -9.14,
#                       'q3': 0.845,
#                       'std': 15.1221},
#           'Hour': {'mean': -12.6813,
#                    'median': -12.0,
#                    'q1': -18.26,
#                    'q3': -2.88,
#                    'std': 12.0468},
#           'Month': {'mean': -1.4866,
#                     'median': -0.57,
#                     'q1': -3.7575,
#                     'q3': 2.5225,
#                     'std': 11.1164},
#           'Precipitation': {'mean': -3.3376,
#                             'median': -0.62,
#                             'q1': -6.51,
#                             'q3': 1.69,
#                             'std': 11.6405}},
#  'SMAPE': {'Boolean Weather Missing Value': {'mean': -6.7859,
#                                              'median': -3.35,
#                                              'q1': -13.9375,
#                                              'q3': 0.4825,
#                                              'std': 13.177},
#            'Day of Week': {'mean': -8.782,
#                            'median': -7.89,
#                            'q1': -18.395,
#                            'q3': 0.61,
#                            'std': 14.7802},
#            'Holiday': {'mean': -3.4443,
#                        'median': -2.14,
#                        'q1': -13.24,
#                        'q3': 2.525,
#                        'std': 22.2795},
#            'Hour': {'mean': -16.3073,
#                     'median': -14.94,
#                     'q1': -23.68,
#                     'q3': -6.14,
#                     'std': 13.74},
#            'Month': {'mean': -1.3961,
#                      'median': -0.125,
#                      'q1': -7.9925,
#                      'q3': 3.17,
#                      'std': 14.8443},
#            'Precipitation': {'mean': -3.8372,
#                              'median': -0.895,
#                              'q1': -10.0725,
#                              'q3': 2.24,
#                              'std': 13.3844}}}
