# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../src_Prophet_combinations/results/all_combinations_results.csv')

# %%
df.head()
# Out:
#                                dataset                  model       mae  \
# 0  stretchedSociety_block_91_MAC001165        Prophet_holiday  0.057069
# 1  stretchedSociety_block_91_MAC001165          Prophet_month  0.057656
# 2  stretchedSociety_block_91_MAC001165           Prophet_hour  0.057121
# 3  stretchedSociety_block_91_MAC001165  Prophet_dayofweek_num  0.057204
# 4  stretchedSociety_block_91_MAC001165     Prophet_precipType  0.057085
#
#            mape     smape      rmse  training_time
# 0  4.114941e+13  0.466129  0.119137       0.685529
# 1  4.280527e+13  0.465400  0.119215       0.602493
# 2  4.156366e+13  0.464706  0.119188       0.822524
# 3  4.087302e+13  0.466888  0.119309       0.895181
# 4  4.128353e+13  0.465975  0.119153       0.714298

# %%
df.groupby(['dataset','model']).max()
# Out:
#                                                                                                  mae  \
# dataset                                 model
# establishedAffluence_block_10_MAC001221 Prophet_bool_weather_missing_values                 0.234868
#                                         Prophet_bool_weather_missing_values_dayofweek_num   0.238901
#                                         Prophet_bool_weather_missing_values_dayofweek_n...  0.237600
#                                         Prophet_bool_weather_missing_values_dayofweek_n...  0.237161
#                                         Prophet_bool_weather_missing_values_dayofweek_n...  0.239632
# ...                                                                                              ...
# stretchedSociety_block_99_MAC004799     Prophet_hour_month_precipType                       0.106624
#                                         Prophet_hour_precipType                             0.105922
# ...

# %%
sns.set_theme(style="ticks")

# %%
for house in df.dataset.unique():
    casas = df[df['dataset'].isin([house])]
    
    f, ax = plt.subplots(figsize=(7, 6))

    sns.boxplot(
        casas, x="mae", y="dataset", hue="dataset",
        whis=[0, 100], width=.6, palette="vlag"
    )

    # Add in points to show each observation
    sns.stripplot(casas, x="mae", y="dataset", size=4, color=".3")

    # Tweak the visual presentation
    ax.xaxis.grid(True)
    ax.set(ylabel="")
    sns.despine(trim=True, left=True)
# Out:
# /tmp/ipykernel_234521/3520146029.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   f, ax = plt.subplots(figsize=(7, 6))
