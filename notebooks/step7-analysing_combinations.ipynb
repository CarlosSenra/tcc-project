# %%
import pandas as pd

# %%
df = pd.read_csv('../src_Prophet_combinations/results/all_combinations_results.csv')

# %%
casa = lambda row : row[-1][-4:]

# %%
df['house_id'] = df.dataset.str.split('_').apply(casa)

# %%
df
# Out:
#                                       dataset  \
# 0         stretchedSociety_block_91_MAC001165
# 1         stretchedSociety_block_91_MAC001165
# 2         stretchedSociety_block_91_MAC001165
# 3         stretchedSociety_block_91_MAC001165
# 4         stretchedSociety_block_91_MAC001165
# ...                                       ...
# 6421  establishedAffluence_block_27_MAC003016
# 6422  establishedAffluence_block_22_MAC004694
# 6423      stretchedSociety_block_94_MAC000870
# 6424  establishedAffluence_block_33_MAC004965
# 6425     stretchedSociety_block_109_MAC005547
#
#                                                   model       mae  \
# 0                                       Prophet_holiday  0.057069
# 1                                         Prophet_month  0.057656
# 2                                          Prophet_hour  0.057121
# 3                                 Prophet_dayofweek_num  0.057204
# 4                                    Prophet_precipType  0.057085
# ...

# %%
df[df.house_id == '1243'].to_csv('house_1243_results.csv')

# %%
df[df.house_id == '1243'][31:]
# Out:
#                                   dataset  \
# 3932  stretchedSociety_block_96_MAC001243
# 3933  stretchedSociety_block_96_MAC001243
# 3934  stretchedSociety_block_96_MAC001243
# 3935  stretchedSociety_block_96_MAC001243
# 3936  stretchedSociety_block_96_MAC001243
# 3937  stretchedSociety_block_96_MAC001243
# 3938  stretchedSociety_block_96_MAC001243
# 3939  stretchedSociety_block_96_MAC001243
# 3940  stretchedSociety_block_96_MAC001243
# 3941  stretchedSociety_block_96_MAC001243
# 5517  stretchedSociety_block_96_MAC001243
# 5518  stretchedSociety_block_96_MAC001243
# 5519  stretchedSociety_block_96_MAC001243
# 5520  stretchedSociety_block_96_MAC001243
# 5521  stretchedSociety_block_96_MAC001243
# 5522  stretchedSociety_block_96_MAC001243
# 5523  stretchedSociety_block_96_MAC001243
# 5524  stretchedSociety_block_96_MAC001243
# 5525  stretchedSociety_block_96_MAC001243
# 5526  stretchedSociety_block_96_MAC001243
# 5527  stretchedSociety_block_96_MAC001243
# ...
